# %%
f = open("7.txt", "r")
lines = f.read().splitlines()

# %%
from dataclasses import field, dataclass
from typing import TypeVar

FS = TypeVar('FS')

@dataclass
class FS:
    name: str
    parent: FS = None
    dirs: list[FS] = field(default_factory=list)
    files: list[tuple] = field(default_factory=list)

    def goto(self, dname) -> FS:
        if dname == '..':
            return self.parent
        for d in self.dirs:
            if d.name == dname:
                return d

    def total_size(self) -> int:
        s = sum(e[1] for e in self.files)
        s += sum(d.total_size() for d in self.dirs)
        return s

    def add_child(self, name):
        if not any(1 for d in self.dirs if d.name == name):
            self.dirs.append(FS(name, self))

    def add_file(self, name, size):
        if not any(1 for e in self.files if e[1] == name):
            self.files.append((name, size))

# %%
print(FS('a'))
# Out:
# FS(name='a', parent=None, dirs=[], files=[])

# %%
root = FS('/')
curr = root
readdir = False
for line in lines:
    if line[0] == '$':
        readdir = False
        _, cmd, *n = line.split()
        match cmd:
            case 'cd':
                n,=n
                if n != '/':
                    curr = curr.goto(n)
            case 'ls':
                readdir = True
                continue
    elif readdir:
        a, b, *_ = line.split()
        if a == 'dir':
            curr.add_child(b)
        else:
            curr.add_file(b, int(a))

# %%
from pprint import pprint
pprint(root)
# Out:
# FS(name='/',
#    parent=None,
#    dirs=[FS(name='bjrbjh',
#             parent=...,
#             dirs=[],
#             files=[('ctprm.bpc', 80731)]),
#          FS(name='dppgvlh',
#             parent=...,
#             dirs=[FS(name='rtdnhb',
#                      parent=...,
#                      dirs=[],
#                      files=[('ctprm.bpc', 295880)])],
#             files=[('bbjw', 180122), ('ctprm.bpc', 210923), ('hhg', 304465)]),
#          FS(name='fcfqp',
#             parent=...,
#             dirs=[FS(name='cts',
#                      parent=...,
#                      dirs=[],
#                      files=[('nhzpb', 47983)]),
#                   FS(name='gjzdf',
#                      parent=...,
#                      dirs=[FS(name='fcfqp',
#                               parent=...,
#                               dirs=[],
#                               files=[('vcbnl', 145412)])],
#                      files=[('vtrhs.mlh', 161310)]),
#                   FS(name='hvsnr',
#                      parent=...,
#                      dirs=[FS(name='sftjlqbm',
#                               parent=...,
#                               dirs=[],
#                               files=[('qlgp', 96517)])],
#                      files=[]),
#                   FS(name='qmsllmtw',
#                      parent=...,
#                      dirs=[],
#                      files=[('hhg', 172998)]),
#                   FS(name='rpvstz',
#                      parent=...,
#                      dirs=[FS(name='nccm',
#                               parent=...,
#                               dirs=[],
#                               files=[('fcfqp', 181998)]),
#                            FS(name='tsstr',
#                               parent=...,
#                               dirs=[],
#                               files=[('tsstr', 258571)])],
#                      files=[]),
#                   FS(name='vbhh',
#                      parent=...,
#                      dirs=[FS(name='rpvstz',
#                               parent=...,
#                               dirs=[FS(name='fcfqp',
#                                        parent=...,
#                                        dirs=[FS(name='hrhftz',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('vlrjptvv.fsr',
#                                                         163301)])],
#                                        files=[]),
#                                     FS(name='nzg',
#                                        parent=...,
#                                        dirs=[FS(name='qsbpc',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('hqvhrpnv.phh', 74559),
#                                                        ('tqb.wnl', 322306)])],
#                                        files=[('hhg', 230765),
#                                               ('ptg.dbs', 235220),
#                                               ('vtttmhf.dcl', 220737)]),
#                                     FS(name='pmhprnbb',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('hhg', 293892)]),
#                                     FS(name='szshbn',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('tsstr.pml', 303519)])],
#                               files=[]),
#                            FS(name='scsclh',
#                               parent=...,
#                               dirs=[FS(name='rdznzm',
#                                        parent=...,
#                                        dirs=[FS(name='hthgb',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('gjgczrpm.hlw', 2762)]),
#                                              FS(name='vgfhz',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('svplfhqh.rfr', 160621),
#                                                        ('vcbnl', 27592)])],
#                                        files=[('zjlcp', 270085)])],
#                               files=[])],
#                      files=[('ctprm.bpc', 317169),
#                             ('vcbnl', 307868),
#                             ('zbltwtj', 118337)]),
#                   FS(name='zwllwsq',
#                      parent=...,
#                      dirs=[FS(name='bmgpnmbt',
#                               parent=...,
#                               dirs=[FS(name='fcfqp',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('wqtnzw.cvj', 16285)])],
#                               files=[('hhg', 67327),
#                                      ('qrgrtg.gtn', 175579),
#                                      ('rdrtvn', 185356)]),
#                            FS(name='fbphbmbb',
#                               parent=...,
#                               dirs=[FS(name='fpnwjb',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('pgv.snz', 78102),
#                                               ('wqtnzw.szw', 32886)]),
#                                     FS(name='hqvhrpnv',
#                                        parent=...,
#                                        dirs=[FS(name='drpffn',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('wdhl.dgs', 204660)]),
#                                              FS(name='fvqzjjhp',
#                                                 parent=...,
#                                                 dirs=[FS(name='qtc',
#                                                          parent=...,
#                                                          dirs=[],
#                                                          files=[('wgfffz',
#                                                                  74576)])],
#                                                 files=[]),
#                                              FS(name='szdbbtw',
#                                                 parent=...,
#                                                 dirs=[FS(name='fcfqp',
#                                                          parent=...,
#                                                          dirs=[],
#                                                          files=[('bthq.wlm',
#                                                                  56006)])],
#                                                 files=[]),
#                                              FS(name='vvrhmrbs',
#                                                 parent=...,
#                                                 dirs=[FS(name='sqwfj',
#                                                          parent=...,
#                                                          dirs=[FS(name='chjpwmb',
#                                                                   parent=...,
#                                                                   dirs=[],
#                                                                   files=[('ctprm.bpc',
#                                                                           305407)])],
#                                                          files=[('fcfqp.wrn',
#                                                                  170226)])],
#                                                 files=[('vcbnl', 21051)])],
#                                        files=[('ctprm.bpc', 247435),
#                                               ('hqvhrpnv', 312573),
#                                               ('swbvbwd', 103964),
#                                               ('trjpn.htm', 129434),
#                                               ('vgjnhmbc.hcr', 33772)]),
#                                     FS(name='jbm',
#                                        parent=...,
#                                        dirs=[FS(name='jwbrhmzj',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('zqmldh.jwc', 22219)]),
#                                              FS(name='tsstr',
#                                                 parent=...,
#                                                 dirs=[FS(name='rmbpb',
#                                                          parent=...,
#                                                          dirs=[],
#                                                          files=[('mzvb',
#                                                                  185176),
#                                                                 ('vcbnl',
#                                                                  204877)])],
#                                                 files=[('ctprm.bpc', 141377),
#                                                        ('jhwr.tvf', 28965)])],
#                                        files=[('fcfqp', 138219),
#                                               ('mbvpfmgs.lbq', 67905),
#                                               ('mzvb', 125465),
#                                               ('vrqpss.qtr', 211711)]),
#                                     FS(name='jsfscjd',
#                                        parent=...,
#                                        dirs=[FS(name='tws',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('dnrswnh', 244925),
#                                                        ('vcbnl', 307737)])],
#                                        files=[('jqwcrvg', 210670),
#                                               ('qcv.crz', 263796),
#                                               ('slcgw.hmz', 23224)]),
#                                     FS(name='qmpbb',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('fcfqp.pgc', 175766),
#                                               ('nnrgl.qtd', 155950),
#                                               ('rjjw', 215226),
#                                               ('rpvstz.cls', 218856)]),
#                                     FS(name='sjhrg',
#                                        parent=...,
#                                        dirs=[FS(name='dbdc',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('cqfmgtr.fpp', 159323)]),
#                                              FS(name='jprmnvv',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('ctprm.bpc', 314162)]),
#                                              FS(name='wbqrzrcd',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('mzvb', 177804),
#                                                        ('wfmhd.srn', 11757)])],
#                                        files=[]),
#                                     FS(name='tsstr',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('hhg', 303871),
#                                               ('mzvb', 311124)])],
#                               files=[('tsstr.czd', 79487),
#                                      ('tvdpb.vss', 226172)]),
#                            FS(name='hqvhrpnv',
#                               parent=...,
#                               dirs=[],
#                               files=[('mzvb', 75235)])],
#                      files=[('hhg', 217873)])],
#             files=[('hqvhrpnv', 61601),
#                    ('hqvhrpnv.sgf', 27922),
#                    ('mzvb', 191405),
#                    ('nbjp.fdm', 263646)]),
#          FS(name='mtbt',
#             parent=...,
#             dirs=[FS(name='gtgdhl',
#                      parent=...,
#                      dirs=[],
#                      files=[('hsjc', 305753)]),
#                   FS(name='hqvhrpnv',
#                      parent=...,
#                      dirs=[FS(name='dzrlrdc',
#                               parent=...,
#                               dirs=[],
#                               files=[('wqtnzw.tpr', 65797)]),
#                            FS(name='fcfqp',
#                               parent=...,
#                               dirs=[],
#                               files=[('hhg', 141146)]),
#                            FS(name='spz',
#                               parent=...,
#                               dirs=[],
#                               files=[('gjgczrpm.hlw', 292906),
#                                      ('gjn.ptw', 202319),
#                                      ('vcbnl', 311120),
#                                      ('wqtnzw', 93748)])],
#                      files=[('cvt.pwb', 131065),
#                             ('hqvhrpnv.gjg', 175755),
#                             ('jjpnjhqz.wtf', 313719),
#                             ('nhr.vtv', 3622)]),
#                   FS(name='pdhn',
#                      parent=...,
#                      dirs=[FS(name='rjgsq',
#                               parent=...,
#                               dirs=[],
#                               files=[('ctprm.bpc', 424)])],
#                      files=[]),
#                   FS(name='ptmpqgj',
#                      parent=...,
#                      dirs=[FS(name='rpvstz',
#                               parent=...,
#                               dirs=[],
#                               files=[('gjnpwldn.jsh', 248549),
#                                      ('nstp.jpj', 31443)]),
#                            FS(name='wqtnzw',
#                               parent=...,
#                               dirs=[],
#                               files=[('mzvb', 47276)])],
#                      files=[('mdnllcs', 10127), ('npbr', 178992)]),
#                   FS(name='qfdmhqhm',
#                      parent=...,
#                      dirs=[],
#                      files=[('wqtnzw.qrn', 254322)]),
#                   FS(name='tsstr',
#                      parent=...,
#                      dirs=[],
#                      files=[('cqbs.thq', 265555), ('ggnr', 273707)]),
#                   FS(name='ttjltb',
#                      parent=...,
#                      dirs=[],
#                      files=[('cmln.qlj', 82810), ('mzvb', 23429)])],
#             files=[('bqvdgj.tdt', 277478),
#                    ('hnmvhb.dqb', 100015),
#                    ('tsstr.crd', 178843),
#                    ('vbqjdj.znj', 45660),
#                    ('vch.zrz', 204359)]),
#          FS(name='qtfmf',
#             parent=...,
#             dirs=[FS(name='hrl',
#                      parent=...,
#                      dirs=[FS(name='dwgnv',
#                               parent=...,
#                               dirs=[FS(name='mrhvqqc',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('qbhmdfwg.wrt', 113150)])],
#                               files=[]),
#                            FS(name='lgn',
#                               parent=...,
#                               dirs=[],
#                               files=[('gzzdwd.wnn', 293311)]),
#                            FS(name='qhcjcc',
#                               parent=...,
#                               dirs=[],
#                               files=[('fcfqp', 298893),
#                                      ('lvb.brw', 253573),
#                                      ('ndbrjbw.ssq', 301515),
#                                      ('vmdgmm.gmh', 236001),
#                                      ('wqtnzw.cqd', 124715)]),
#                            FS(name='rpvstz',
#                               parent=...,
#                               dirs=[FS(name='hqvhrpnv',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('vrtgr.vdt', 271956)]),
#                                     FS(name='rpvstz',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('cjcf.rwc', 185836),
#                                               ('vcbnl', 289321)]),
#                                     FS(name='tbdnjbmr',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('ctprm.bpc', 124297),
#                                               ('hhg', 323010)])],
#                               files=[]),
#                            FS(name='zrqf',
#                               parent=...,
#                               dirs=[FS(name='fcfqp',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('cdfldlv.ptw', 1896)]),
#                                     FS(name='vrp',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('fmmvbft.rjq', 5610)])],
#                               files=[])],
#                      files=[]),
#                   FS(name='mnb',
#                      parent=...,
#                      dirs=[FS(name='tsstr',
#                               parent=...,
#                               dirs=[],
#                               files=[('gjgczrpm.hlw', 172859)])],
#                      files=[('ctprm.bpc', 64404)]),
#                   FS(name='rfghjdj',
#                      parent=...,
#                      dirs=[],
#                      files=[('cpfclgj.wqh', 78613)]),
#                   FS(name='tsstr',
#                      parent=...,
#                      dirs=[FS(name='cjdbwvn',
#                               parent=...,
#                               dirs=[FS(name='hqvhrpnv',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('tdzsmzw', 43899)])],
#                               files=[('wqtnzw.gcq', 264636),
#                                      ('zvpwlrbr.nnz', 124125)]),
#                            FS(name='lsv',
#                               parent=...,
#                               dirs=[FS(name='vdltrlzg',
#                                        parent=...,
#                                        dirs=[FS(name='nlchndbr',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('vcbnl', 134010)])],
#                                        files=[])],
#                               files=[('hhg', 202987), ('vcbnl', 251479)])],
#                      files=[('gjgczrpm.hlw', 135418)]),
#                   FS(name='wqtnzw',
#                      parent=...,
#                      dirs=[FS(name='hqvhrpnv',
#                               parent=...,
#                               dirs=[],
#                               files=[('ctprm.bpc', 50703)])],
#                      files=[])],
#             files=[('hqvhrpnv', 108080), ('qrfjg', 85284)]),
#          FS(name='sfjrs',
#             parent=...,
#             dirs=[FS(name='cgl',
#                      parent=...,
#                      dirs=[FS(name='tdwn',
#                               parent=...,
#                               dirs=[],
#                               files=[('lzqfb.tgc', 119119)])],
#                      files=[]),
#                   FS(name='cjjls',
#                      parent=...,
#                      dirs=[FS(name='hgppstcv',
#                               parent=...,
#                               dirs=[],
#                               files=[('bvt', 223932),
#                                      ('hhg', 85898),
#                                      ('ppbrb.vtq', 195499)])],
#                      files=[]),
#                   FS(name='rfwnnr',
#                      parent=...,
#                      dirs=[],
#                      files=[('gmzchms.wst', 96712), ('mzvb', 271527)]),
#                   FS(name='rpvstz',
#                      parent=...,
#                      dirs=[],
#                      files=[('cbj.mlh', 78920)]),
#                   FS(name='tsstr',
#                      parent=...,
#                      dirs=[],
#                      files=[('bdlrvwv', 17373), ('vcbnl', 50170)])],
#             files=[('hhg', 184472), ('pdswzfq.scs', 241700)]),
#          FS(name='trtl',
#             parent=...,
#             dirs=[FS(name='dflwctzs',
#                      parent=...,
#                      dirs=[],
#                      files=[('fcfqp.qcg', 6196), ('mrjvtvl.hmm', 181057)]),
#                   FS(name='gsl',
#                      parent=...,
#                      dirs=[FS(name='gmlp',
#                               parent=...,
#                               dirs=[],
#                               files=[('qmtmtppc', 167819),
#                                      ('sbn.chs', 254187),
#                                      ('tbhhgmz.vqs', 119156),
#                                      ('tptqzrqr.zgh', 31966)]),
#                            FS(name='mjrs',
#                               parent=...,
#                               dirs=[],
#                               files=[('fcfqp.jgz', 167756),
#                                      ('tzj.rfb', 221559)]),
#                            FS(name='rpvstz',
#                               parent=...,
#                               dirs=[],
#                               files=[('hhg', 93065)])],
#                      files=[('wqtnzw.hpl', 91777)]),
#                   FS(name='jlfrcp',
#                      parent=...,
#                      dirs=[FS(name='fcfqp',
#                               parent=...,
#                               dirs=[FS(name='tdflqz',
#                                        parent=...,
#                                        dirs=[FS(name='dtvnrl',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('mzvb', 277524)])],
#                                        files=[]),
#                                     FS(name='thjdsqmw',
#                                        parent=...,
#                                        dirs=[FS(name='chhf',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('ctprm.bpc', 6278)]),
#                                              FS(name='hsnrrc',
#                                                 parent=...,
#                                                 dirs=[FS(name='bphrpw',
#                                                          parent=...,
#                                                          dirs=[FS(name='brj',
#                                                                   parent=...,
#                                                                   dirs=[],
#                                                                   files=[('rpvstz.bqh',
#                                                                           13067)]),
#                                                                FS(name='hqvhrpnv',
#                                                                   parent=...,
#                                                                   dirs=[FS(name='fsvgbd',
#                                                                            parent=...,
#                                                                            dirs=[],
#                                                                            files=[('ctprm.bpc',
#                                                                                    222743),
#                                                                                   ('vwp.nnq',
#                                                                                    80460)])],
#                                                                   files=[('ctprm.bpc',
#                                                                           148840),
#                                                                          ('hghq.gqm',
#                                                                           94116)]),
#                                                                FS(name='rpvstz',
#                                                                   parent=...,
#                                                                   dirs=[],
#                                                                   files=[('ctprm.bpc',
#                                                                           287030),
#                                                                          ('rhpt',
#                                                                           145932)])],
#                                                          files=[]),
#                                                       FS(name='dmjvnrhz',
#                                                          parent=...,
#                                                          dirs=[FS(name='mlh',
#                                                                   parent=...,
#                                                                   dirs=[],
#                                                                   files=[('tsstr.vfl',
#                                                                           238301)])],
#                                                          files=[]),
#                                                       FS(name='rpvstz',
#                                                          parent=...,
#                                                          dirs=[],
#                                                          files=[('mcv', 59172)]),
#                                                       FS(name='wqtnzw',
#                                                          parent=...,
#                                                          dirs=[],
#                                                          files=[('tlwnzqgb.dqq',
#                                                                  50806)])],
#                                                 files=[]),
#                                              FS(name='tsstr',
#                                                 parent=...,
#                                                 dirs=[FS(name='rpvstz',
#                                                          parent=...,
#                                                          dirs=[],
#                                                          files=[('mzvb',
#                                                                  109284)])],
#                                                 files=[]),
#                                              FS(name='wqtnzw',
#                                                 parent=...,
#                                                 dirs=[FS(name='hwpdsfg',
#                                                          parent=...,
#                                                          dirs=[],
#                                                          files=[('vbbrvhqm.mvj',
#                                                                  295333)]),
#                                                       FS(name='mrn',
#                                                          parent=...,
#                                                          dirs=[],
#                                                          files=[('mzvb', 46589),
#                                                                 ('pppwz',
#                                                                  235773),
#                                                                 ('rsrbq.qdl',
#                                                                  69304)])],
#                                                 files=[('rpvstz.pdq', 183742)])],
#                                        files=[('qgt.sdb', 218719),
#                                               ('twvn', 134210)])],
#                               files=[('fcfqp.dtr', 265006), ('vshqb', 136055)]),
#                            FS(name='hmlmvqc',
#                               parent=...,
#                               dirs=[],
#                               files=[('ctprm.bpc', 77344),
#                                      ('hhg', 291828),
#                                      ('rpvstz.qfl', 226384),
#                                      ('tpmdrpg.hcj', 10758)]),
#                            FS(name='pqmfswh',
#                               parent=...,
#                               dirs=[],
#                               files=[('bczcpjln.ffs', 127361),
#                                      ('ctprm.bpc', 208033),
#                                      ('hqvhrpnv.bzm', 144048),
#                                      ('pgf.ltz', 88561),
#                                      ('twj.drs', 149879)]),
#                            FS(name='qghq',
#                               parent=...,
#                               dirs=[],
#                               files=[('hqvhrpnv.mqb', 165758)]),
#                            FS(name='trhs',
#                               parent=...,
#                               dirs=[FS(name='bnrqbrv',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('ltjjfp', 150034)]),
#                                     FS(name='snd',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('hqvhrpnv', 21614),
#                                               ('wvtc', 95241)])],
#                               files=[('rlnln.gcv', 177929), ('rpvstz', 60631)]),
#                            FS(name='tsstr',
#                               parent=...,
#                               dirs=[FS(name='cdvgvc',
#                                        parent=...,
#                                        dirs=[FS(name='gvssnh',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('fpqgb.nbl', 20979)]),
#                                              FS(name='nhrvzn',
#                                                 parent=...,
#                                                 dirs=[FS(name='hqvhrpnv',
#                                                          parent=...,
#                                                          dirs=[],
#                                                          files=[('hhg',
#                                                                  202973)]),
#                                                       FS(name='nlv',
#                                                          parent=...,
#                                                          dirs=[],
#                                                          files=[('hqvhrpnv',
#                                                                  235158),
#                                                                 ('hqvhrpnv.vmg',
#                                                                  246378),
#                                                                 ('rfzjcbpv.crc',
#                                                                  278166)])],
#                                                 files=[]),
#                                              FS(name='rpvstz',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('tsstr.wjh', 181642)]),
#                                              FS(name='wqtnzw',
#                                                 parent=...,
#                                                 dirs=[FS(name='pgnzftwn',
#                                                          parent=...,
#                                                          dirs=[FS(name='njtgddhw',
#                                                                   parent=...,
#                                                                   dirs=[],
#                                                                   files=[('fvbr',
#                                                                           75203)])],
#                                                          files=[('sqwmjb',
#                                                                  217983),
#                                                                 ('wqtnzw.pzv',
#                                                                  149152)])],
#                                                 files=[])],
#                                        files=[('hqvhrpnv', 121417),
#                                               ('hqvhrpnv.dnl', 180690),
#                                               ('psj.fdv', 266104),
#                                               ('rww.nbt', 278434)]),
#                                     FS(name='mbmn',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('hhg', 82237),
#                                               ('hqvhrpnv.hcf', 36010)]),
#                                     FS(name='mprbjtnd',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('gbrvbz.rgc', 23927),
#                                               ('hqvhrpnv', 20857),
#                                               ('zpbhr.svj', 203364)]),
#                                     FS(name='rvwqgn',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('fcfqp.mdf', 291142),
#                                               ('gjgczrpm.hlw', 124256),
#                                               ('mzvb', 235579)]),
#                                     FS(name='tvtddch',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('dshzl.plf', 317689),
#                                               ('vphnqd', 44518)])],
#                               files=[('tsstr', 8263)])],
#                      files=[('mrtwp', 256413),
#                             ('mzvb', 141186),
#                             ('nvwfhv.rvt', 106340),
#                             ('qmmgnjh', 274275),
#                             ('wbtf', 55881)]),
#                   FS(name='pfnlc',
#                      parent=...,
#                      dirs=[FS(name='vdsjh',
#                               parent=...,
#                               dirs=[],
#                               files=[('pzs', 202584)]),
#                            FS(name='wfvgc',
#                               parent=...,
#                               dirs=[],
#                               files=[('ctmrb.qsq', 315910)])],
#                      files=[]),
#                   FS(name='pjj',
#                      parent=...,
#                      dirs=[FS(name='wzv',
#                               parent=...,
#                               dirs=[],
#                               files=[('clrchzw.vbj', 221150)])],
#                      files=[('qhngjlvt.pcb', 242824)]),
#                   FS(name='vmjljc',
#                      parent=...,
#                      dirs=[FS(name='blm',
#                               parent=...,
#                               dirs=[FS(name='hqvhrpnv',
#                                        parent=...,
#                                        dirs=[FS(name='tsstr',
#                                                 parent=...,
#                                                 dirs=[FS(name='fzrpgcn',
#                                                          parent=...,
#                                                          dirs=[],
#                                                          files=[('hhg',
#                                                                  10603)])],
#                                                 files=[]),
#                                              FS(name='wqtnzw',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('ctprm.bpc', 56612),
#                                                        ('fljtffmz.rcl', 22521)]),
#                                              FS(name='zphvcch',
#                                                 parent=...,
#                                                 dirs=[FS(name='fcfqp',
#                                                          parent=...,
#                                                          dirs=[],
#                                                          files=[('ctprm.bpc',
#                                                                  171787),
#                                                                 ('mzvb',
#                                                                  134010)])],
#                                                 files=[])],
#                                        files=[]),
#                                     FS(name='pvnrmvb',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('fcfqp.nzt', 100624),
#                                               ('mzvb', 120945)]),
#                                     FS(name='pvt',
#                                        parent=...,
#                                        dirs=[FS(name='lslcvfv',
#                                                 parent=...,
#                                                 dirs=[FS(name='gmj',
#                                                          parent=...,
#                                                          dirs=[],
#                                                          files=[('drpztfvs.shg',
#                                                                  174220)])],
#                                                 files=[('tcbf', 13666)]),
#                                              FS(name='wvhrf',
#                                                 parent=...,
#                                                 dirs=[FS(name='nvvpbmgm',
#                                                          parent=...,
#                                                          dirs=[FS(name='tllpvrdv',
#                                                                   parent=...,
#                                                                   dirs=[],
#                                                                   files=[('lmqcbbz',
#                                                                           309970)])],
#                                                          files=[('pzht',
#                                                                  241543),
#                                                                 ('rmhrd',
#                                                                  72906)])],
#                                                 files=[('gqggsrc', 19033),
#                                                        ('hhg', 270841)])],
#                                        files=[('mzvb', 8511),
#                                               ('srnqlrn.lvg', 81176),
#                                               ('ttzwwnn.fmz', 315976)]),
#                                     FS(name='rjpcb',
#                                        parent=...,
#                                        dirs=[FS(name='gqql',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('wctr.qnb', 214991)])],
#                                        files=[('fcfqp.gjw', 215654),
#                                               ('gjgczrpm.hlw', 241891),
#                                               ('sqjtc', 101620)]),
#                                     FS(name='srrzgt',
#                                        parent=...,
#                                        dirs=[FS(name='bwfnrbs',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('gpsmlzbp.ghd',
#                                                         133922)]),
#                                              FS(name='qdctrw',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('ppp', 56213)]),
#                                              FS(name='svpm',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('hhg', 205352)]),
#                                              FS(name='tsstr',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('fcfqp.hlg', 248839),
#                                                        ('lfdlfrhs.vjz',
#                                                         299835)])],
#                                        files=[('hhg', 147738)])],
#                               files=[('hjsjqbw.rst', 249527),
#                                      ('slp.gbn', 161576),
#                                      ('wtps.brr', 97355)]),
#                            FS(name='fcfqp',
#                               parent=...,
#                               dirs=[FS(name='ctbbgw',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('vcbnl', 306172)]),
#                                     FS(name='rpvstz',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('hhg', 40277),
#                                               ('mllhtfm.jwd', 225110)])],
#                               files=[('wqtnzw.cts', 265076)]),
#                            FS(name='frjdzh',
#                               parent=...,
#                               dirs=[],
#                               files=[('jlscvz.lsw', 69285)]),
#                            FS(name='scjhzc',
#                               parent=...,
#                               dirs=[],
#                               files=[('gjgczrpm.hlw', 221073)]),
#                            FS(name='tmz',
#                               parent=...,
#                               dirs=[FS(name='tsn',
#                                        parent=...,
#                                        dirs=[],
#                                        files=[('mzvb', 196121)]),
#                                     FS(name='wjszmnp',
#                                        parent=...,
#                                        dirs=[FS(name='pbtmjghf',
#                                                 parent=...,
#                                                 dirs=[],
#                                                 files=[('vcbnl', 151036)]),
#                                              FS(name='smbbnl',
#                                                 parent=...,
#                                                 dirs=[FS(name='wqtnzw',
#                                                          parent=...,
#                                                          dirs=[],
#                                                          files=[('hhg', 203547),
#                                                                 ('wqtnzw.dgs',
#                                                                  220352)])],
#                                                 files=[('mbt', 299800)])],
#                                        files=[])],
#                               files=[('fcfqp', 35287),
#                                      ('mnz.zwd', 146224),
#                                      ('mzvb', 189997),
#                                      ('ttwjfbl.jbb', 31655),
#                                      ('wqtnzw.slq', 170705)]),
#                            FS(name='vpvh',
#                               parent=...,
#                               dirs=[],
#                               files=[('vbgrhzjs.tdb', 69506)]),
#                            FS(name='zcwpb',
#                               parent=...,
#                               dirs=[],
#                               files=[('fcfqp.hpq', 73403)])],
#                      files=[('dbtnn', 31640)])],
#             files=[('hhg', 168166),
#                    ('mzvb', 97874),
#                    ('qzlwgts', 186837),
#                    ('tnb.mpv', 132833)])],
#    files=[('mzvb', 95962)])

# %%
root.total_size()
# Out:
# 43562874

# %%
def sum_sizes(n):
    s = n.total_size() if n.total_size() <= 100000 else 0
    return sum(sum_sizes(d) for d in n.dirs) + s
sum_sizes(root)
# Out:
# 1886043

# %%
print(sum_sizes(root))
# Out:
# 1886043

# %%
free = 70000000 - root.total_size()
candidate = lambda x: x.total_size() + free >= 30000000

# %%
ds = []
def search(n):
    if candidate(n):
        ds.append(n)
    for d in n.dirs:
        search(d)

# %%
search(root)
min = ds[0].total_size()
for d in ds:
    if d.total_size() < min:
        min = d.total_size()
print(min)
# Out:
# 3842121
